# %% [markdown]
# # DAV versie 1

# %%
# Load library
import numpy as np
import pandas as pd
import json
import csv

# %%
# load part of dataset
with open("dataset.csv") as fIn, open("dataset_test1.csv", "w") as fOut:
    counter = 0   
    for line in fIn:
        line.strip('\n')
        if counter < 500:
            fOut.write(line)
        counter = counter + 1

# %%
# skip empty lines
with open("dataset_test1.csv") as fIn, open("dataset_test2.csv", "w") as fOut:    
    for line in fIn:
        if line.strip() != '':
            fOut.write(line)

# %%
# read csv
dataset = pd.read_csv("dataset_test2.csv", sep=',')

dataset
# Out:
#      incident_id        date                 state    city_or_county  \
# 0         461105  2013-01-01          Pennsylvania        Mckeesport
# 1         460726  2013-01-01            California         Hawthorne
# 2         478855  2013-01-01                  Ohio            Lorain
# 3         478925  2013-01-05              Colorado            Aurora
# 4         478959  2013-01-07        North Carolina        Greensboro
# 5         478948  2013-01-07              Oklahoma             Tulsa
# 6         479363  2013-01-19            New Mexico       Albuquerque
# 7         479374  2013-01-21             Louisiana       New Orleans
# 8         479389  2013-01-21            California         Brentwood
# 9         492151  2013-01-23              Maryland         Baltimore
# 10        491674  2013-01-23             Tennessee       Chattanooga
# 11        479413  2013-01-25              Missouri       Saint Louis
# 12        479561  2013-01-26             Louisiana         Charenton
# ...

# %%
# first 5 lines
dataset[:5]
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
dataset['state'].value_counts()[:5]
# Out:
# California      44
# New York        29
# New Jersey      26
# Illinois        25
# Pennsylvania    24
# Name: state, dtype: int64

# %%
dataset[dataset['state'] == 'California']
# Out:
#      incident_id        date       state   city_or_county  \
# 1         460726  2013-01-01  California        Hawthorne
# 8         479389  2013-01-21  California        Brentwood
# 16        479580  2013-02-03  California    Yuba (county)
# 19        480311  2013-02-11  California          Vallejo
# 22        480358  2013-02-19  California  Orange (county)
# 25        480407  2013-02-23  California        Lancaster
# 30        481213  2013-03-04  California        Los Banos
# 35        482801  2013-03-13  California        Oceanside
# 37        482838  2013-03-14  California          Modesto
# 38        482926  2013-03-16  California             Galt
# 39        482934  2013-03-17  California         Stockton
# 44        483835  2013-03-30  California  Merced (county)
# 48        483878  2013-04-07  California       Long Beach
# 50        484279  2013-04-10  California          Vallejo
# 66        486056  2013-05-05  California        Palo Alto
# ...

# %%
dataset[dataset['state'].str.contains("a")]['state'].unique()


# complaints[complaints['Complaint Type'].str.contains("Noise")]['Complaint Type'].unique()
# Out:
# array(['Pennsylvania', 'California', 'Colorado', 'North Carolina',
#        'Oklahoma', 'Louisiana', 'Maryland', 'District of Columbia',
#        'Delaware', 'Utah', 'Michigan', 'Georgia', 'Indiana', 'Florida',
#        'Washington', 'South Carolina', 'Arizona', 'Virginia',
#        'Rhode Island', 'Texas', 'Alabama', 'Kansas', 'West Virginia',
#        'Minnesota', 'Nevada', 'Nebraska', 'Massachusetts', 'Hawaii',
#        'New Hampshire', 'Iowa', 'Alaska', 'Arkansas'], dtype=object)

# %%
dataset.drop(['incident_url','source_url', 'incident_url_fields_missing', 'sources'], axis=1, inplace=True)

file_name = 'dataset_final.csv'
dataset.to_csv(file_name, sep=',')

dataset
# Out:
#      incident_id        date                 state    city_or_county  \
# 0         461105  2013-01-01          Pennsylvania        Mckeesport
# 1         460726  2013-01-01            California         Hawthorne
# 2         478855  2013-01-01                  Ohio            Lorain
# 3         478925  2013-01-05              Colorado            Aurora
# 4         478959  2013-01-07        North Carolina        Greensboro
# 5         478948  2013-01-07              Oklahoma             Tulsa
# 6         479363  2013-01-19            New Mexico       Albuquerque
# 7         479374  2013-01-21             Louisiana       New Orleans
# 8         479389  2013-01-21            California         Brentwood
# 9         492151  2013-01-23              Maryland         Baltimore
# 10        491674  2013-01-23             Tennessee       Chattanooga
# 11        479413  2013-01-25              Missouri       Saint Louis
# 12        479561  2013-01-26             Louisiana         Charenton
# ...

# %%
## HIER GAAT HET OM
## DOEL: DE KOLOM particpant_name
## vervangen door dictionary. Dus bv '0::Julian Sims' wordt {'0': 'Julian Sims'}

# selecteer dataset
column = dataset['participant_name']
counter = 0 

# loop door rijen van participant_name kolom
for row in column:    
    
#     als rij niet leeg is (soms is ie leeg)
    if not pd.isnull(row):
        cleanrow = row.split("||")
        
#         maak er een dictonary van
        splitted_dict = {}
        for element in cleanrow:
            index, status = element.split("::")
            splitted_dict[index] = status

        
#             nu het probleem: hoe zorgen we dat we die dictionary weer opslaan in de database? 
#         dataset['participant_name'].iloc[counter] = splitted_dict
    counter = counter + 1     

# dataset

# %%
csvfile = open('dataset_final.csv', 'r')
jsonfile = open('dataset.json', 'w')

reader = csv.DictReader(csvfile)
for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')
