# %% [markdown]
# # DAV exploratory data analysis - MAP

# %%
# import pandas, numpy, json
import numpy as np
import pandas as pd
import json
import csv

# %%
# Importing bokeh 
from bokeh.plotting import figure, save
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, FactorRange, LogColorMapper
from bokeh.models import PanTool, ResetTool, WheelZoomTool, HoverTool, LassoSelectTool, BoxSelectTool

# alleen deze voor googlemaps
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap

# %%
# load json
df = pd.read_json("dataset.json", lines=True)
df
# Out:
#                                                   address  \
# 0               1506 Versailles Avenue and Coursin Street
# 1                            13500 block of Cerise Avenue
# 2                                   1776 East 28th Street
# 3                        16000 block of East Ithaca Place
# 4                               307 Mourning Dove Terrace
# 5                              6000 block of South Owasso
# 6                                          2806 Long Lane
# 7       LaSalle Street and Martin Luther King Jr. Boul...
# 8                              1100 block of Breton Drive
# 9                            1500 block of W. Fayette St.
# 10                                         1501 Dodds Ave
# 11                    W Florissant Ave and Riverview Blvd
# 12                           1000 block of Flat Town Road
# 13                            2403 Benning Road Northeast
# 14                                   601 West Main Street
# ...

# %%
###
# read incidnets json
###
df_p = pd.read_json("dataset_incidents.json", lines=True)
print('done')

# fill empty values with 'nan'
df_p = dict_df.replace(np.nan, 'NaN', regex=True)
df_p

# %%
####
## GOOGLE MAPz 2.0 
###

coordinates = pd.concat([df['incident_id'], df['state'], df['latitude'], df['longitude']], axis=1, keys=['id','state', 'lat', 'lon'])
psource = ColumnDataSource(coordinates)

output_file("gmap.html")

map_options = GMapOptions(lat=40.0000, lng=-100.0000, map_type="roadmap", zoom=4)

API_key = "AIzaSyCJEv5ycF5vALgOG5pbIaUt8ACCCvYhs40"
p = gmap(API_key, map_options, title="Gun Violence incidents", plot_width=800, plot_height=400)

my_hover = HoverTool()
my_hover.tooltips = [('State of this point', '@state'), ['Incident ID: ', '@id']]
p.add_tools(my_hover)


# p.circle('x', 'y', source=psource, color='red', size=10)
p.circle(x="lon", y="lat", size=1, fill_color="blue", fill_alpha=0.8, source=psource)

show(p)
output_file('plot_map.html')
# save(p)

# %%
######
# KAN WEG?
# lat/lon zonder 'nan'
######

# get latlist without 'nan'
latlist = data['latitude'].tolist()
latlist = [str(i) for i in latlist]
latlist_nonan = []
for element in latlist:
    if element != 'nan':
        latlist_nonan.append(element)


# get lonlist without 'nan'
lonlist = data['longitude'].tolist()
lonlist = [str(i) for i in lonlist]
lonlist_nonan = []
for element in lonlist:
    if element != 'nan':
        lonlist_nonan.append(element)


latlondata = pd.DataFrame(list(zip(latlist_nonan, lonlist_nonan)))
latlondata.columns = ['lat', 'lon']

# %%
# data year
yearlist = []
for index, row in data.iterrows():
    year = str(row['date'])[:4]
    yearlist.append(year)

df_year = pd.DataFrame({'year':yearlist})
    
coordinates = pd.concat([df_year, data['incident_id'], data['latitude'], data['longitude']], axis=1, keys=['year', 'id', 'lat', 'lon'])

coordinates
# Out:
# done

# %%
## GOOGLE MAPz 3.0 
###
from bokeh.layouts import column
from bokeh.layouts import row, widgetbox
from bokeh.models import CustomJS, Slider



# coordinates = pd.concat([yearlist, data['incident_id'], data['latitude'], data['longitude']], axis=1, keys=['year', 'id', 'lat', 'lon'])
psource = ColumnDataSource(coordinates)


output_file("gmap.html")

map_options = GMapOptions(lat=40.0000, lng=-100.0000, map_type="roadmap", zoom=4)

API_key = "AIzaSyCJEv5ycF5vALgOG5pbIaUt8ACCCvYhs40"
p = gmap(API_key, map_options, title="Gun Violence incidents", plot_width=800, plot_height=400)

my_hover = HoverTool()
my_hover.tooltips = [('Incident ID: ', '@id'), ('Year: ', '@year')]
p.add_tools(my_hover)


# p.circle('x', 'y', source=psource, color='red', size=10)
p.circle(x="lon", y="lat", size=1, fill_color="blue", fill_alpha=0.8, source=psource)


callback = CustomJS(args=dict(source=psource), code="""
    var data = source.data;
    var f = cb_obj.value
    var x = data['x']
    var y = data['y']
    psource.change.emit();
""")


y_slider = Slider(start=2013, end=2017, value=1, step=1, title="Year Slider")
y_slider.js_on_change('value', callback)


# Define the callback function: update_plot
def update_plot(attr, old, new):
    # set the `yr` name to `slider.value` and `source.data = new_data`
    yr = slider.value
    new_data = {
        'x'       : data.loc[yr].fertility,
        'y'       : data.loc[yr].life,
    }
    source.data = new_data
    
    

layout = column(p, widgetbox(y_slider),
)
show(layout)

output_file('plot_map_layout.html')
save(layout)
# Out:
# '/Users/Casper/Documents/UvA/DAV/plot_map_layout.html'

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import Figure, output_file, show

output_file("js_on_change.html")

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = Figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var f = cb_obj.value
    var x = data['x']
    var y = data['y']
    for (var i = 0; i < x.length; i++) {
        y[i] = Math.pow(x[i], f)
    }
    source.change.emit();
""")

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power")
slider.js_on_change('value', callback)

layout = column(slider, plot)

show(layout)
