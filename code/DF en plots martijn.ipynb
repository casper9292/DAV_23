# %%
import numpy as np
import pandas as pd
import json
import csv

from bokeh.plotting import figure
from bokeh.io import output_file, show, save
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge
from bokeh.core.properties import value
from bokeh.models import PanTool, ResetTool, WheelZoomTool, HoverTool, LassoSelectTool, BoxSelectTool

# %%
df = pd.read_json("dataset.json", lines=True)

# %%
df_p = pd.read_json('dataset_incidents.json', lines=True)

# %%
df_suspect = df_p
df_test = df_suspect.groupby([ "participant_relationship",'participant_age']).size().reset_index(name="count")
# df_relationships = df_relationship.drop(df_relationship.index[11])
# df_relationship



# for index, row in df_relationship.iterrows():
#     print(row)

df_relationships = df_test.loc[df_test['participant_relationship'].str.contains("NaN")==False]
# print(df_aquaintance)
df_relationships.set_index('participant_relationship')
df_relationship = df_relationships.loc[df_relationships['participant_relationship'].str.contains('Aquaintance')==False]
df_relationship

# for index, row in df_relationship.iterrows():
#     if "Significant others" or "Neighbor" or "Mass Shooting" or "Family" or "Friends" in row:
#         df_relationship = df_relationship.drop(row)
#     else:
#         continue
# df_relationship
# Out:
#                    participant_relationship  participant_age  count
# 65                            Armed Robbery              0.0      2
# 66                            Armed Robbery              1.0      2
# 67                            Armed Robbery              2.0      2
# 68                            Armed Robbery              3.0      3
# 69                            Armed Robbery              4.0      2
# 70                            Armed Robbery              5.0      3
# 71                            Armed Robbery              6.0      2
# 72                            Armed Robbery              8.0      1
# 73                            Armed Robbery             10.0      2
# 74                            Armed Robbery             11.0      1
# 75                            Armed Robbery             12.0      2
# 76                            Armed Robbery             13.0     10
# 77                            Armed Robbery             14.0     29
# ...

# %%
df_suspect = df_p.loc[(df_p['participant_type'] == "Subject-Suspect")]
df_relationships = df_suspect.groupby([ "participant_relationship"])
# df_relationships = df_relationship.drop(df_relationship.index[11])

df_relationships.describe()

# # df_relation_age = df_relationship.set_index('participant_age')
# df_relations = df_relationship.groupby('participant_relationship')
# df_relations.describe()
# # for index, row in df_relationship.iterrows():

# #     print(row)

# df_aquaintance = df_relationship.loc[df_relationship['participant_relationship'].str.contains("Family")==True]
# # print(df_aquaintance)
# df_aquaintance

# %%
df_suspect = df_p
df_test = df_suspect.groupby([ "participant_relationship",'participant_age']).size().reset_index(name="count")
# df_relationships = df_relationship.drop(df_relationship.index[11])
df_relationship



# for index, row in df_relationship.iterrows():
#     print(row)

df_relationship = df_test.loc[df_test['participant_relationship'].str.contains("NaN")==False]
# print(df_aquaintance)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['Male','Female','C','D'],
'Armed Robbery': [29.6, 30.9, 30, 4],
'Friends': [27.6, 29.5, 2, 34],
'Family': [34.7, 37.8, 23, 24],
'Gang vs Gang': [23.4, 26.4, 33, 14],
'Significant Others': [38.5, 37.4, 32, 14]
})
 
 
 
# ------- PART 1: Create background
 
# number of variable
categories=list(df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(90)
plt.yticks([10,20,30,40], ["10","20","30",'40'], color="grey", size=10)
plt.ylim(0,40)
 
 
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Male")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Female")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.01, 0.01))

# %%
df_gender = df_p.loc[df_p['participant_gender'].str.contains('Female')==True]
df_year = df_gender.loc[df_gender['']]
df_male = df_gender.groupby('participant_relationship')['participant_age']
df_male.describe()

# %%
from bokeh.models import DataRange1d
import bokeh.models
output_file("iris.html")

# Create the figure object
f = figure(plot_width=1000, plot_height=650)

relation = df_relationship[df_relationship["participant_relationship"] == "relation"]


# Now we make a rather small change, namely

# If you get an BAD_COLUMN_NAME error. Reset your kernel. In the next version of Bokeh this will be fixed,
# But at the moment the keys do not update when the data is edited. So running the code multiple times, can
# sometimes result in conflicts.
relation_cds = ColumnDataSource(relation)



# Adding glyphs
f.circle(x=df_relationship["count"], y=df_relationship["participant_age"])

# Save and show the figure


# Dictionary to map name of the species to a color
colormap = {
    'Family' : 'red',
    'Friends' : 'green',
    'Significant other - current or otherwise' : 'blue',
    'Aquaintance' : '#424242',
    'Gang vs Gang' : '#424242',
    'Armed Robbery' : 'orange',
    'Home Invasion': '#424242',
    'Co-worker': '#424242',
    'Drive by - Random victims': '#424242',
    'Home Invasion - Perp Does Not Know Victim': '#424242',
    'Home Invasion - Perp Knows Victim': 'amber',
    'Mass shooting - Random victims': 'brown',
    'Mass shooting - Perp Knows Victims' :'black',
    
    'Neighbor': '#424242',
    'Significant others - current or former': 'teal'
    
}

# Adding a column to the DataFrame (using list comprehension to make the contents of the column)
df_relationship['color'] = [colormap[x] for x in df_relationship['participant_relationship']]

# Now we define the figure again, and this time add the color to the circle plot:

#############################################################################
# Define the output file path
output_file("iris.html")

# Create the figure object
f = figure(plot_width=1000, plot_height=650)

## Adding some style
# You can also use Hex-codes and RGB tuples for the color
f.background_fill_color= '#424242'
# f.background_fill_alpha=0.3

## Add a Title to the plot (We essentially use css properties here)
# You can find all function of f.title, using dir(f.title)
f.title.text="Age and Relationship"
f.title.text_font_size="25px"
f.title.align="center"

## Add some axis information (after all, a plot without axis descriptions is nothing more than abstract art)
f.xaxis.axis_label="Suspect Age"
f.yaxis.axis_label="Reported number of incidents"

# Maybe add some different colors for the labels and the digits as well
# Note how we use f.axis, to apply to both the x and y axis.
f.axis.axis_label_text_color="grey"
f.axis.major_label_text_color="grey"

# Axes geometry
f.x_range=DataRange1d(start=0, end=96)
f.y_range=DataRange1d(start=0, end=350)

hover = HoverTool(tooltips=[("(x,y)", "($x, $y)"), ('relation' , '@relation') ])

# Now we just pick a semi-random selection of tools
f.toolbar.tools = [PanTool(), ResetTool(), WheelZoomTool(), hover, LassoSelectTool(), BoxSelectTool()]

# And let us just move it to the top instead of the side.
f.toolbar_location='above'

#############################################################################
f.circle(x=df_relationship["participant_age"], y=df_relationship["count"], size =df_relationship['count']/3, 
         fill_alpha=0.2, color=df_relationship['color'])
show(f)

# %%
relationships = ['NaN','Aquaintance','Co-worker','Drive by - Random victims', 'Family','Friends', 'Gang vs Gang','Home Invasion - Perp Does Not Know Victim','Home Invasion - Perp Knows Victim','Mass shooting - Random victims','NaN','Neighbor','Significant others - current or former']

# %%
# maakt nieuwe columns met de maand en het jaar

df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# zet de index op month
iets = df.set_index(['month'])
iets

# zet index op jaar en dan maand
lekker = df.set_index(['year','month'])
lekker
# # df_date = df.loc[df['incident_characteristics'].str.contains('Officer', 'officer')==True].groupby('month')['n_killed','n_injured']
# # df_date.describe()

# ok = df


# groupies = df.groupby(['year','month'])['n_injured','n_killed']
# groupies.describe()
# Out:
#                                                       address  \
# year month
# 2013 1              1506 Versailles Avenue and Coursin Street
#      1                           13500 block of Cerise Avenue
#      1                                  1776 East 28th Street
#      1                       16000 block of East Ithaca Place
#      1                              307 Mourning Dove Terrace
#      1                             6000 block of South Owasso
#      1                                         2806 Long Lane
#      1      LaSalle Street and Martin Luther King Jr. Boul...
#      1                             1100 block of Breton Drive
#      1                           1500 block of W. Fayette St.
#      1                                         1501 Dodds Ave
#      1                    W Florissant Ave and Riverview Blvd
#      1                           1000 block of Flat Town Road
#      1                            2403 Benning Road Northeast
# ...

# %%
# selecteer op man en maak onderscheid suspect en victim
man = df_p.loc[df_p['participant_gender']=='Male']
suspect_man = man.loc[man['participant_type']=='Subject-Suspect']
victim_man = man.loc[man['participant_type']=='Victim']

# maak een dict met de het aantal gevallen per leeftijd voor suspect en victim
leeftijden_man_suspect = suspect_man['participant_age'].value_counts().to_dict()
leeftijden_man_victim = victim_man['participant_age'].value_counts().to_dict()

# selecteer op vrouw en maak onderscheid suspect en victim
woman = df_p.loc[df_p['participant_gender']=='Female']
suspect_woman = woman.loc[woman['participant_type']=='Subject-Suspect']
victim_woman = woman.loc[woman['participant_type']=='Victim']

# maak een dict met de het aantal gevallen per leeftijd voor suspect 
leeftijden_woman_suspect = suspect_woman['participant_age'].value_counts().to_dict()
leeftijden_woman_victim = victim_woman['participant_age'].value_counts().to_dict()



# order de dicts en zet in lijst, nieuwe variabelen voor elke groep
x = []
y = []
for  k, v in sorted(leeftijden_man_victim.items()):
   
    x.append(k)
    y.append(v)

x1 = []
y1 = []
for  k, v in sorted(leeftijden_man_suspect.items()):
   
    x1.append(k)
    y1.append(v)

x2 = []
y2 = []
for  k, v in sorted(leeftijden_woman_victim.items()):
   
    x2.append(k)
    y2.append(v)
    
x3 = []
y3 = []
for  k, v in sorted(leeftijden_woman_suspect.items()):
   
    x3.append(k)
    y3.append(v)

# %%
# Maak plots


output_file("Gender_age_division_type.html")

p = figure(x_range = (0,100), y_range=(0,6000), title = 'Age division by gender')

p.line(x, y, line_width=2, line_color = "#47A8E5")
p.circle(x, y, size=2,  fill_color = '#47A8E5', line_color="#47A8E5", line_width=3, legend='Male Victim')

p.line(x1, y1, line_width=2, line_color = '#133A7C')
p.circle(x1, y1, size=2,  fill_color = '#133A7C', line_color="#133A7C", line_width=3, legend='Male Suspect')

p.line(x2, y2, line_width=2, line_color = "#FF0800")
p.circle(x2, y2, size=2,  fill_color = '#FF0800', line_color="#FF0800", line_width=3, legend='Female Victim')

p.line(x3, y3, line_width=2, line_color = "#800000")
p.circle(x3, y3, size=2,  fill_color = '#800000', line_color="#800000", line_width=3, legend='Female Suspect')



p.xaxis.axis_label = "Age"
p.xaxis.axis_label_text_color = "#aa6666"
p.xaxis.axis_label_standoff = 30

p.yaxis.axis_label = "Number of Incidents"
p.yaxis.axis_label_text_color = '#aa6666'

show(p)

# %%
#maak een df met de jaren en maand als index
ieks = lekker.groupby(['year','month']).size().reset_index(name='count').to_dict()

#voeg bijbehorende key en values toe aan lijst 
maanden = []
count = []
for i in range(0,63):
    maanden.append(i+1)
    count.append(ieks['count'][i])
    
# maak een lineare regressie lijst
regression = np.polyfit(maanden, count, 1)

print(regression)

# nu de waarden invullen voor de regressie
r_x, r_y = zip(*((i, i*regression[0] + regression[1]) for i in range(63)))
# Out:
# [  79.28485023 1267.26574501]

# %%
output_file("Month_incidents_troughout.html")

p = figure(x_range = (1,63), y_range=(0,5800), title = 'Number of incidents per month')

p.line(maanden, count, line_width=2, line_color = "#47A8E5")
p.circle(maanden, count, size=2,  fill_color = '#47A8E5', line_color="#47A8E5", line_width=3)


p.line(r_x, r_y, line_width=2, line_color = "red")


p.xaxis.axis_label = "Month"
p.xaxis.axis_label_text_color = "#aa6666"
p.xaxis.axis_label_standoff = 30

p.yaxis.axis_label = "Number of Incidents"
p.yaxis.axis_label_text_color = '#aa6666'

show(p)

# %%
a =[]
b = []

for  k, v in sorted(nieuw.items()):
    a.append(k)
    b.append(v)
b
# Out:
# [23091,
#  18841,
#  22639,
#  18628,
#  19930,
#  18755,
#  21126,
#  21040,
#  19656,
#  19890,
#  17974,
#  18106]

# %%
output_file("Month_incidents.html")

p = figure(x_range = (1,12), y_range=(0,25000), title = 'Number of incidents per month')

p.line(a, b, line_width=2, line_color = "#47A8E5")
p.circle(a, b, size=2,  fill_color = '#47A8E5', line_color="#47A8E5", line_width=3)



p.xaxis.axis_label = "Month of the Year"
p.xaxis.axis_label_text_color = "#aa6666"
p.xaxis.axis_label_standoff = 30

p.yaxis.axis_label = "Number of Incidents"
p.yaxis.axis_label_text_color = '#aa6666'

show(p)

# %%
df_test
# Out:
#                    participant_relationship  participant_age  count
# 0                               Aquaintance              1.0      1
# 1                               Aquaintance              9.0      1
# 2                               Aquaintance             11.0      1
# 3                               Aquaintance             13.0      1
# 4                               Aquaintance             14.0      9
# 5                               Aquaintance             15.0     12
# 6                               Aquaintance             16.0     17
# 7                               Aquaintance             17.0     27
# 8                               Aquaintance             18.0     32
# 9                               Aquaintance             19.0     38
# 10                              Aquaintance             20.0     26
# 11                              Aquaintance             21.0     31
# 12                              Aquaintance             22.0     37
# ...
